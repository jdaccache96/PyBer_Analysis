# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode = [0,0,0,0,0,0,.2,0,0,0,0,0]
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
plt.subplots(figsize=(4, 4))
plt.pie(y_axis, 
        explode=explode,
        colors=colors,
        labels=x_axis,
        autopct='%.1f%%')

plt.show()

# %%
#Creating a pie chart using the Object-Oriented Method
fig, ax=plt.subplots()
ax.pie(y_axis, labels=x_axis)
plt.show()

# %%
#Adding errors bars to line chart: can show standard deviation, standard error, confidence intervals, or min/max values 
#USING MATLAB METHOD
plt.errorbar(x,y, yerr= <value>)
plt.errorbar
# Out:
#   Cell In[37], line 3
#     plt.errorbar(x,y, yerr= <value>)
#                             ^
# SyntaxError: invalid syntax
